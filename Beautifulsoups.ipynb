# %%
from requests_html import HTML
from bs4 import BeautifulSoup
import html
import pandas as pd
import requests
import re

# %%
header={
    
    
"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"
        
        
      }
url="https://tez.yok.gov.tr/UlusalTezMerkezi/tezSorguSonucYeni.jsp"
get=requests.get(url,headers=header)
print(get.status_code)
# Out:
# 200

# %%
#prettify is important to see code clearly
#tag=doc.find_all("")

# %%
#for link in soup.find_all():
 #   print(link.get('https://tez.yok.gov.tr/UlusalTezMerkezi/tezSorguSonucYeni.jsp'))
#print(soup.get_text("https://tez.yok.gov.tr/UlusalTezMerkezi/tezSorguSonucYeni.jsp"))

# %%
#url="https://tez.yok.gov.tr/UlusalTezMerkezi/tezSorguSonucYeni.jsp"
#result=requests.get(url)
#print(result.text)
#doc=BeautifulSoup(result.text,"html.parser")
#print(doc.prettify())
#tezdetay=doc.find("script")
#print(tezdetay)
with open('Desktop/Iqus/bs.html',encoding="utf8") as a:
   doc=BeautifulSoup(a,"html.parser")
print(doc.prettify())
tags=doc.find_all("div")
print(div)
#tag=doc.find_all("div") basic version
#print(tag)
#tag=doc.find_all(["div"],style_")
tag=doc.find_all("td")
print(tag)
td=doc.td
tdall=td.contents
print(tdall)
#print(list(tdall[0].children\decendants))
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="Aydın Emre Ceviz;Aytaç Akkaya" name="author"/>
#   <meta content="Yükseköğretim Kurulu Tez Merkezi'nde bulunan basılı bütün tezleri tarayarak, üye olduktan sonra izinli tezlere tam metin(pdf) olarak erişebilirisiniz." name="description"/>
#   <meta content="Yök, Yükseköğretim Kurulu Başkanlığı, Tez, Thesis, Dissertation" name="keywords"/>
#   <link href="css/style.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="css/ustMenu.css" rel="stylesheet" type="text/css"/>
#   <link href="css/jquery.jcarousel.css" media="all" rel="stylesheet" type="text/css">
#    <!--[if IE 6]>
# 		<link rel="stylesheet" href="css/ie6.css" type="text/css" media="all" />
# 	<![endif]-->
#    <link href="css/images/favicon.ico" rel="shortcut icon"/>
# ...

# %%
split?
# Out:
# Object `split` not found.

# %%
# Out:
# [<td nowrap="nowrap" width="100%">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <div id="navigation2">
# <ul>
# <li class="menu"><a href="giris.jsp">Ana Sayfa</a></li>
# <li class="menu"><a href="tarama.jsp">Tarama</a></li>
# <li class="menu"><a href="tezTeslimKilavuz.jsp">Mevzuat</a></li>
# <li class="menu"><a href="istatistikler.jsp">İstatistikler</a></li>
# <li class="menu"><a href="sss.jsp">SSS</a></li>
# <li class="menu"><a href="yasalUyari.jsp">Yasal Uyarı</a></li>
# <li class="menu"><a href="sistemGiris.jsp">Bize Ulaşın      </a></li>
# </ul>
# <div>
# </div>
# </div></td>, <td align="center" height="500" valign="top" width="100%">
# <div id="dialog-modal" style="display:none" title="Tez Bilgileri Detay">
# <p>Tez detay yükleniyor...</p>
# </div>
# <div id="divuyari" style="width:100%;padding:2px 0px 2px 0px;display: inline-block; background-color: #F9F9F9;color: #0088CC;text-decoration: none;">
# Tarama sonucunda   6 kayıt bulundu.
#
#
# </div>
# ...

# %%
# Out:
# ['\n', <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>, '\n', <div id="navigation2">
# <ul>
# <li class="menu"><a href="giris.jsp">Ana Sayfa</a></li>
# <li class="menu"><a href="tarama.jsp">Tarama</a></li>
# <li class="menu"><a href="tezTeslimKilavuz.jsp">Mevzuat</a></li>
# <li class="menu"><a href="istatistikler.jsp">İstatistikler</a></li>
# <li class="menu"><a href="sss.jsp">SSS</a></li>
# <li class="menu"><a href="yasalUyari.jsp">Yasal Uyarı</a></li>
# <li class="menu"><a href="sistemGiris.jsp">Bize Ulaşın      </a></li>
# </ul>
# <div>
# </div>
# </div>]
